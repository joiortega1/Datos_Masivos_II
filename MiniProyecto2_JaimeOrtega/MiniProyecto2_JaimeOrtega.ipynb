# %% [markdown]
# # Mini-proyecto: Algoritmo FP-Tree
# - Ortega Ibarra Jaime Jesus.
#
# **Objetivo del mini-proyecto:**
#
# Implementar el código del algoritmo FP-Tree en una libreta usando python.
# Requisitos:
# - La identificación de los elementos frecuentes deberá realizarse con al menos dos valores de soporte diferentes describiendo qué observaste y si se repitió algún conjunto de elementos.
# - El código debe estar debidamente documentado y funcionando.
# - Para la identificación de los elementos frecuentes deberás usar la siguiente base de datos: Groceries dataset (https://www.kaggle.com/heeraldedhia/groceries-dataset?select=Groceries_dataset.csv)

# %% [markdown]
# # Exploración de los datos
#
# Mediante la librería $Pandas$ realizamos la lectura de los datos para poder visualizarlos.

# %%
import pandas as pd

# %%
data = pd.read_csv('Groceries_dataset.csv')

# %%
data.head()
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk

# %%
len(data)
# Out:
# 38765

# %%
len(data['itemDescription'].value_counts())
# Out:
# 167

# %% [markdown]
# - Contamos con 38765 Registros
# - Los datos se dividen en:
#     + Member_number: Número de la membresía con la cual se realizó la compra
#     + Date: Fecha de la compra
#     + itemDescription: Producto que se compró

# %% [markdown]
# ### Transformando a transacciones
#
# Dado que se cuenta con la fecha de la compra, así como el número de la membresía, podemos ordenar los diferentes artículos, de tal manera que puedan expresar la compra completa.

# %%
fechas = list(set(data[data['Member_number'] == 3180]["Date"]))

# %%
fechas
# Out:
# ['04-05-2015',
#  '09-11-2014',
#  '15-09-2015',
#  '06-02-2015',
#  '30-07-2014',
#  '24-02-2014',
#  '02-11-2014',
#  '19-10-2015',
#  '03-07-2015',
#  '15-03-2015']

# %%
Membresias = list(set(data["Member_number"]))

# %%
def transacciones(data_frame, membresia,lista):
    '''
    En esta función se realizará un recorrido por todo el conjunto de datos,
    de tal manera que se puedan expresar los diferentes productos como
    una transacción de compra.
    
    Data_frame: Conjunto de datos
    Membresia: Número de membresía dentro del conjunto de datos
    lista: Lista de python en la cual se almacenarán los datos
    '''
    fechas = list(set(data[data['Member_number'] == membresia]["Date"]))
    data_cliente = data[data['Member_number'] == membresia]
    for i in range(len(fechas)):
        freq_temp = []
        transaccion = data_cliente[data_cliente['Date'] == fechas[i]]
        items = list(transaccion['itemDescription'])
        freq_temp.append(items)
        freq.append(freq_temp)

# %%
def quitar_corchetes(text):
    '''
    Recibe los diferentes datos de tipo String y realiza una limpieza para 
    eliminar carácteres no deseados.
    
    text: Cadena de texto
    '''
    acentos = (("[", " "),
        ("]", " "))
    for i, k in acentos:
        text = text.replace(i, k).replace(i.upper(), k.upper())
    return text

# %%
freq = []
for i in range(len(Membresias)):
    transacciones(data, Membresias[i], freq)

# %%
Transacciones = pd.DataFrame(freq)
Transacciones.columns = ['Transacciones']

# %%
for i in range(len(Transacciones)):
    Transacciones['Transacciones'][i] = (quitar_corchetes(str(Transacciones['Transacciones'][i])))

# %% [markdown]
# Como podemos observar en la siguiente tabla, encontramos los artículos que se han comprado por cada diferente membresía en cada fecha diferente.

# %%
Transacciones.head()
# Out:
#                                        Transacciones
# 0                     'sausage', 'hygiene articles'
# 1                  'canned beer', 'misc. beverages'
# 2             'whole milk', 'pastry', 'salty snack'
# 3                      'soda', 'pickled vegetables'
# 4   'sausage', 'whole milk', 'semi-finished bread...

# %%
total_items = ''
for i in range(len(Transacciones)):
    total_items += str(Transacciones['Transacciones'][i]).replace("\n", ",")

# %%
def normalizar(text):
    '''
    Función que nos ayudará a normalizar nuestros artículos
    
    text: Cadena de texto
    '''
    text = text.replace("[^a-zA-Z#]", " ")
    text = text.lower()
    acentos = (
        ("."," "),
        (","," "),
        ("”", " "),
        ("“", " "),
        ("'", " ")
    )
    for i, k in acentos:
        text = text.replace(i, k).replace(i.upper(), k.upper())
    return text

# %%
text1 = normalizar(total_items)
text1 = text1.split("    ")

# %%
len(text1)
# Out:
# 38765

# %% [markdown]
# ## Obtenemos los productos más frecuentes
#
# Para este punto decidimos realizar mediante dos diferentes soportes $0.03$ y $0.05$

# %% [markdown]
# ## Frecuencia

# %%
def frecuencias(data):
    '''
    Esta función recibe un conjunto de datos, dado esto obtiene la cantidad de ocasiones 
    que se repiten los diferentes items (Frecuencia).
    
    Data: Conjunto de datos'''
    frecuencias = []
    valores = list(set(data["itemDescription"]))
    for k in range(len(valores)):
        aux = 0
        for i in range(len(data)):
            if data["itemDescription"][i] == valores[k]:
                aux += 1
        frecuencias.append(aux)
    return frecuencias

# %%
frecuencias_values = frecuencias(data)

# %%
len(frecuencias_values)
# Out:
# 167

# %% [markdown]
# Almacenamos nuestras frecuencias en una lista y a su vez las añadimos dentro de un $DataFrame$ junto con los valores únicos dentro de los items, los cuales obtenemos mediante la función $set()$

# %%
Frecuencia = pd.DataFrame(set(data["itemDescription"]))
Frecuencia["Frecuencia"] = frecuencias_values

# %%
Frecuencia.columns = ["Elementos", "Frecuencia"]

# %%
Frecuencia.head(10)
# Out:
#                   Elementos  Frecuencia
# 0                 skin care          20
# 1                 ice cream         227
# 2                     pasta         121
# 3                 margarine         491
# 4  female sanitary products          40
# 5                    dishes         135
# 6                 nut snack          22
# 7    house keeping products          45
# 8                  cookware          17
# 9            instant coffee          61

# %% [markdown]
# ## Frecuencia Sup = 0.03
#
# Para obtener el soporte únicamente dividimos la frecuencia de cada uno de nuestros items, entre el total de transacciones.

# %%
soportes = []
for i in range(len(frecuencias_values)):
    soportes.append(frecuencias_values[i]/len(Transacciones))
Frecuencia["Soporte"] = soportes

# %% [markdown]
# ### Filtramos nuestros datos con un soporte mínimo de 0.03 y ordenamos de acuerdo a su frecuencia

# %%
Freq_minsup3 = Frecuencia[Frecuencia["Soporte"] >= 0.03]
Freq_minsup3 = Freq_minsup3.sort_values(by = "Frecuencia", ascending=False)
Freq_minsup3
# Out:
#                  Elementos  Frecuencia   Soporte
# 68              whole milk        2502  0.167212
# 133       other vegetables        1898  0.126846
# 23              rolls/buns        1716  0.114683
# 144                   soda        1514  0.101183
# 56                  yogurt        1334  0.089153
# 134        root vegetables        1071  0.071577
# 165         tropical fruit        1032  0.068970
# 114          bottled water         933  0.062354
# 98                 sausage         924  0.061752
# 123           citrus fruit         812  0.054267
# 154                 pastry         785  0.052463
# 113              pip fruit         744  0.049723
# 117          shopping bags         731  0.048854
# 136            canned beer         717  0.047918
# 26            bottled beer         687  0.045913
# 74      whipped/sour cream         662  0.044242
# 94              newspapers         596  0.039832
# 104            frankfurter         580  0.038762
# 43             brown bread         571  0.038161
# 121          domestic eggs         566  0.037827
# 161                   pork         566  0.037827
# 21                  butter         534  0.035688
# 152  fruit/vegetable juice         518  0.034619
# 140                   beef         516  0.034485
# 157                   curd         514  0.034351
# 3                margarine         491  0.032814
# 110                 coffee         476  0.031812

# %%
print("Elementos con soporte mínimo = 0.03: ", len(Freq_minsup3))
# Out:
# Elementos con soporte mínimo = 0.03:  27

# %% [markdown]
# Con el siguiente ciclo, vamos a recorrer cada una de nuestras transacciones, comparando con nuestros items más frecuentes obtenidos en la tabla anterior, ordenados de manera descendente, en caso de que estos sean iguales serán almacenado dentro de una lista, la cual será almacenada dentro de otra lista y de esta manera obtendremos una lista final con las transacciones con los productos más frecuentes.

# %%
trans_list = []
for k in range(len(Transacciones)):
    trans_frec = []
    for j in range(len(Freq_minsup3)): 
        for i in range(len(Transacciones['Transacciones'][k].replace("'", "").split(", "))):
            Transaccions = Transacciones['Transacciones'][k].replace("'", "")

            if Transaccions.split(", ")[i].replace(" ", "") == Freq_minsup3['Elementos'].values[j].replace(" ", ""):
                items = str(Freq_minsup3['Elementos'].values[j])
                trans_frec.append(items)

    trans_list.append(trans_frec)

# %% [markdown]
# Eliminamos las listas vacías, pues nos inidican transacciones en las cuales no llevaron ningún artículo dentro de nuestra lista de artículos frecuentes.

# %%
Transacciones_final = []
for i in range(len(trans_list)):
    if trans_list[i] != []:
        Transacciones_final.append(trans_list[i])

# %%
print('Número de transacciones frecuentes con Soporte Mínimo de 0.03: ',len(Transacciones_final))
# Out:
# Número de transacciones frecuentes con Soporte Mínimo de 0.03:  13351

# %% [markdown]
# ## Lista de transacciones con artículos más frecuentes.

# %%
Transacciones_final
# Out:
# [['sausage'],
#  ['canned beer'],
#  ['whole milk', 'pastry'],
#  ['soda'],
#  ['whole milk', 'yogurt', 'sausage'],
#  ['whole milk', 'soda'],
#  ['soda', 'whipped/sour cream', 'frankfurter'],
#  ['whole milk', 'rolls/buns', 'sausage'],
#  ['frankfurter', 'curd'],
#  ['beef'],
#  ['other vegetables'],
#  ['tropical fruit'],
#  ['whole milk', 'butter'],
#  ['root vegetables'],
#  ['rolls/buns', 'sausage'],
#  ['rolls/buns', 'rolls/buns'],
#  ['rolls/buns'],
#  ['other vegetables', 'shopping bags'],
#  ['whole milk', 'root vegetables', 'pastry'],
#  ['other vegetables'],
#  ['whole milk', 'tropical fruit', 'pip fruit'],
#  ['whole milk', 'rolls/buns'],
#  ['canned beer'],
#  ['whipped/sour cream', 'margarine'],
#  ['rolls/buns', 'rolls/buns'],
#  ['whole milk'],
#  ['shopping bags'],
#  ['whole milk', 'rolls/buns', 'bottled beer', 'frankfurter', 'frankfurter'],
#  ['rolls/buns', 'bottled water'],
#  ['soda',
#   'yogurt',
#   'yogurt',
#   'root vegetables',
#   'tropical fruit',
#   'domestic eggs'],
#  ['yogurt', 'newspapers'],
#  ['yogurt', 'tropical fruit'],
#  ['pastry'],
#  ['rolls/buns', 'pip fruit'],
#  ['pip fruit', 'coffee'],
#  ['bottled water'],
#  ['bottled water', 'frankfurter'],
#  ['whole milk', 'other vegetables', 'yogurt', 'frankfurter'],
#  ['pastry'],
#  ['rolls/buns', 'bottled water', 'citrus fruit'],
#  ['yogurt', 'frankfurter'],
#  ['rolls/buns', 'root vegetables', 'tropical fruit', 'shopping bags'],
#  ['brown bread'],
#  ['whole milk'],
#  ['whole milk'],
#  ['bottled water'],
#  ['other vegetables'],
#  ['tropical fruit'],
#  ['domestic eggs'],
#  ['whipped/sour cream'],
#  ['whole milk'],
#  ['root vegetables'],
#  ['canned beer'],
#  ['whole milk', 'yogurt', 'sausage', 'bottled beer'],
#  ['whole milk', 'rolls/buns'],
#  ['whole milk', 'citrus fruit'],
#  ['beef'],
#  ['rolls/buns', 'fruit/vegetable juice'],
#  ['bottled beer'],
#  ['pip fruit'],
#  ['rolls/buns', 'pip fruit', 'frankfurter'],
#  ['other vegetables', 'root vegetables'],
#  ['brown bread'],
#  ['yogurt', 'beef'],
#  ['soda', 'shopping bags'],
#  ['other vegetables', 'rolls/buns'],
#  ['root vegetables'],
#  ['domestic eggs'],
#  ['curd'],
#  ['yogurt', 'newspapers', 'butter'],
#  ['shopping bags', 'canned beer'],
#  ['rolls/buns', 'canned beer'],
#  ['rolls/buns'],
#  ['yogurt', 'tropical fruit', 'curd'],
#  ['butter'],
#  ['beef'],
#  ['sausage', 'fruit/vegetable juice'],
#  ['whole milk', 'whipped/sour cream'],
#  ['rolls/buns', 'root vegetables', 'whipped/sour cream'],
#  ['yogurt', 'bottled beer'],
#  ['soda', 'domestic eggs'],
#  ['curd'],
#  ['sausage', 'whipped/sour cream'],
#  ['other vegetables', 'root vegetables', 'tropical fruit'],
#  ['shopping bags', 'coffee'],
#  ['canned beer'],
#  ['rolls/buns', 'sausage'],
#  ['yogurt', 'citrus fruit'],
#  ['root vegetables'],
#  ['butter', 'fruit/vegetable juice'],
#  ['root vegetables', 'root vegetables', 'canned beer', 'whipped/sour cream'],
#  ['rolls/buns'],
#  ['pork'],
#  ['whole milk'],
#  ['rolls/buns', 'bottled water'],
#  ['root vegetables'],
#  ['canned beer'],
#  ['rolls/buns'],
#  ['rolls/buns', 'bottled water'],
#  ['soda', 'butter'],
#  ['other vegetables', 'other vegetables'],
#  ['other vegetables', 'soda', 'butter'],
#  ['whipped/sour cream', 'newspapers'],
#  ['whole milk', 'pastry', 'shopping bags'],
#  ['whipped/sour cream'],
#  ['yogurt', 'root vegetables'],
#  ['fruit/vegetable juice'],
#  ['pastry', 'frankfurter'],
#  ['rolls/buns', 'soda', 'tropical fruit'],
#  ['rolls/buns', 'sausage'],
#  ['bottled water', 'domestic eggs'],
#  ['yogurt', 'pip fruit'],
#  ['tropical fruit', 'newspapers'],
#  ['sausage'],
#  ['whole milk', 'rolls/buns', 'yogurt', 'yogurt'],
#  ['pip fruit'],
#  ['whole milk'],
#  ['whole milk', 'newspapers'],
#  ['fruit/vegetable juice'],
#  ['yogurt', 'canned beer', 'frankfurter'],
#  ['citrus fruit', 'shopping bags'],
#  ['rolls/buns', 'tropical fruit'],
#  ['whole milk', 'pip fruit', 'whipped/sour cream'],
#  ['pip fruit'],
#  ['whole milk', 'sausage', 'pork', 'butter', 'fruit/vegetable juice'],
#  ['other vegetables'],
#  ['whipped/sour cream', 'butter'],
#  ['margarine'],
#  ['rolls/buns'],
#  ['rolls/buns', 'yogurt'],
#  ['root vegetables'],
#  ['whole milk', 'rolls/buns'],
#  ['tropical fruit'],
#  ['whole milk', 'tropical fruit', 'brown bread'],
#  ['yogurt'],
#  ['bottled water', 'citrus fruit'],
#  ['whole milk', 'other vegetables'],
#  ['beef'],
#  ['whole milk', 'rolls/buns', 'citrus fruit'],
#  ['whole milk'],
#  ['tropical fruit'],
#  ['root vegetables', 'curd'],
#  ['other vegetables', 'tropical fruit'],
#  ['fruit/vegetable juice'],
#  ['yogurt', 'yogurt', 'root vegetables', 'butter'],
#  ['whole milk', 'pastry'],
#  ['bottled water', 'pork'],
#  ['soda', 'curd'],
#  ['soda', 'pip fruit'],
#  ['butter'],
#  ['rolls/buns', 'tropical fruit'],
#  ['whole milk', 'rolls/buns', 'soda'],
#  ['margarine'],
#  ['whole milk', 'butter'],
#  ['frankfurter'],
#  ['whole milk'],
#  ['other vegetables'],
#  ['whipped/sour cream'],
#  ['yogurt'],
#  ['yogurt'],
#  ['other vegetables', 'rolls/buns', 'soda'],
#  ['tropical fruit'],
#  ['shopping bags', 'shopping bags'],
#  ['bottled beer'],
#  ['pork', 'coffee'],
#  ['other vegetables', 'tropical fruit'],
#  ['shopping bags', 'beef'],
#  ['whole milk', 'soda'],
#  ['coffee'],
#  ['butter'],
#  ['root vegetables'],
#  ['soda'],
#  ['other vegetables', 'yogurt', 'shopping bags', 'pork'],
#  ['yogurt', 'yogurt', 'margarine'],
#  ['whipped/sour cream', 'frankfurter'],
#  ['bottled water'],
#  ['soda', 'soda'],
#  ['whole milk'],
#  ['rolls/buns'],
#  ['whole milk', 'other vegetables'],
#  ['pastry'],
#  ['bottled beer'],
#  ['soda', 'fruit/vegetable juice'],
#  ['other vegetables'],
#  ['citrus fruit', 'frankfurter', 'margarine'],
#  ['pork'],
#  ['soda', 'yogurt', 'bottled water', 'newspapers'],
#  ['whole milk'],
#  ['other vegetables', 'pip fruit'],
#  ['whipped/sour cream'],
#  ['tropical fruit'],
#  ['soda', 'soda', 'domestic eggs'],
#  ['yogurt', 'root vegetables'],
#  ['other vegetables', 'root vegetables'],
#  ['other vegetables'],
#  ['bottled water', 'sausage'],
#  ['sausage'],
#  ['beef'],
#  ['whipped/sour cream'],
#  ['soda', 'bottled beer', 'fruit/vegetable juice'],
#  ['whole milk', 'root vegetables', 'tropical fruit', 'margarine'],
#  ['whole milk'],
#  ['whole milk', 'other vegetables', 'tropical fruit'],
#  ['whole milk', 'other vegetables', 'yogurt', 'shopping bags', 'butter'],
#  ['whipped/sour cream'],
#  ['rolls/buns'],
#  ['whole milk', 'citrus fruit'],
#  ['rolls/buns'],
#  ['other vegetables', 'root vegetables'],
#  ['whole milk', 'root vegetables'],
#  ['tropical fruit', 'frankfurter'],
#  ['soda'],
#  ['whole milk', 'tropical fruit'],
#  ['beef'],
#  ['rolls/buns', 'tropical fruit'],
#  ['root vegetables', 'bottled beer'],
#  ['shopping bags'],
#  ['whole milk', 'other vegetables'],
#  ['rolls/buns', 'tropical fruit', 'coffee'],
#  ['pork'],
#  ['whole milk', 'tropical fruit'],
#  ['soda', 'yogurt'],
#  ['pork'],
#  ['domestic eggs'],
#  ['tropical fruit', 'bottled beer'],
#  ['rolls/buns', 'pork'],
#  ['brown bread', 'fruit/vegetable juice'],
#  ['citrus fruit'],
#  ['newspapers'],
#  ['yogurt', 'fruit/vegetable juice'],
#  ['canned beer', 'frankfurter'],
#  ['other vegetables'],
#  ['brown bread'],
#  ['brown bread'],
#  ['yogurt', 'bottled water', 'domestic eggs'],
#  ['pip fruit', 'pip fruit', 'curd'],
#  ['shopping bags'],
#  ['fruit/vegetable juice'],
#  ['frankfurter'],
#  ['bottled water', 'citrus fruit', 'frankfurter', 'fruit/vegetable juice'],
#  ['rolls/buns', 'pip fruit'],
#  ['sausage', 'brown bread'],
#  ['bottled water', 'sausage', 'butter'],
#  ['whole milk', 'whole milk', 'coffee'],
#  ['bottled water', 'frankfurter', 'butter'],
#  ['pastry'],
#  ['other vegetables', 'butter'],
#  ['brown bread'],
#  ['rolls/buns', 'soda', 'canned beer'],
#  ['soda', 'tropical fruit'],
#  ['rolls/buns', 'root vegetables'],
#  ['rolls/buns', 'frankfurter', 'curd', 'coffee'],
#  ['soda'],
#  ['bottled water'],
#  ['rolls/buns'],
#  ['soda', 'canned beer'],
#  ['root vegetables'],
#  ['whole milk', 'other vegetables', 'pastry', 'newspapers', 'frankfurter'],
#  ['whole milk', 'tropical fruit'],
#  ['coffee'],
#  ['yogurt'],
#  ['yogurt', 'tropical fruit', 'bottled beer'],
#  ['bottled water'],
#  ['other vegetables', 'beef', 'margarine'],
#  ['soda'],
#  ['whole milk'],
#  ['pork'],
#  ['other vegetables', 'pip fruit'],
#  ['root vegetables', 'citrus fruit'],
#  ['yogurt', 'newspapers'],
#  ['other vegetables', 'soda', 'shopping bags'],
#  ['rolls/buns', 'citrus fruit'],
#  ['canned beer', 'margarine'],
#  ['whipped/sour cream'],
#  ['rolls/buns', 'soda'],
#  ['other vegetables', 'soda', 'butter', 'beef', 'curd'],
#  ['soda'],
#  ['sausage'],
#  ['whole milk', 'other vegetables'],
#  ['whole milk', 'whole milk'],
#  ['sausage', 'pip fruit'],
#  ['coffee'],
#  ['yogurt'],
#  ['whole milk'],
#  ['other vegetables', 'tropical fruit', 'domestic eggs'],
#  ['yogurt'],
#  ['yogurt', 'beef'],
#  ['whole milk'],
#  ['yogurt', 'sausage', 'pastry'],
#  ['other vegetables', 'bottled beer', 'frankfurter'],
#  ['rolls/buns', 'bottled water', 'sausage', 'bottled beer', 'domestic eggs'],
#  ['yogurt', 'newspapers'],
#  ['other vegetables', 'soda', 'root vegetables'],
#  ['shopping bags'],
#  ['domestic eggs'],
#  ['whole milk'],
#  ['newspapers'],
#  ['root vegetables', 'tropical fruit', 'sausage'],
#  ['whole milk', 'sausage'],
#  ['other vegetables'],
#  ['soda', 'tropical fruit'],
#  ['whole milk', 'brown bread'],
#  ['bottled water', 'domestic eggs', 'pork'],
#  ['yogurt', 'shopping bags'],
#  ['pip fruit', 'fruit/vegetable juice'],
#  ['shopping bags', 'whipped/sour cream', 'curd'],
#  ['root vegetables', 'shopping bags'],
#  ['whole milk', 'soda', 'tropical fruit', 'curd'],
#  ['whole milk', 'sausage'],
#  ['whole milk'],
#  ['bottled water', 'whipped/sour cream', 'frankfurter'],
#  ['tropical fruit'],
#  ['other vegetables'],
#  ['rolls/buns', 'shopping bags'],
#  ['root vegetables', 'bottled water'],
#  ['rolls/buns', 'canned beer'],
#  ['whole milk',
#   'yogurt',
#   'tropical fruit',
#   'citrus fruit',
#   'canned beer',
#   'frankfurter'],
#  ['citrus fruit'],
#  ['pork'],
#  ['root vegetables'],
#  ['pip fruit', 'brown bread'],
#  ['whole milk', 'yogurt'],
#  ['soda', 'butter'],
#  ['brown bread'],
#  ['whole milk'],
#  ['other vegetables', 'rolls/buns', 'whipped/sour cream'],
#  ['yogurt', 'brown bread'],
#  ['other vegetables'],
#  ['root vegetables'],
#  ['yogurt'],
#  ['pastry'],
#  ['yogurt', 'domestic eggs'],
#  ['other vegetables', 'rolls/buns', 'yogurt'],
#  ['yogurt', 'root vegetables'],
#  ['whole milk', 'pork'],
#  ['other vegetables'],
#  ['whole milk', 'yogurt', 'tropical fruit', 'bottled water'],
#  ['citrus fruit'],
#  ['rolls/buns'],
#  ['rolls/buns', 'shopping bags'],
#  ['newspapers'],
#  ['rolls/buns', 'shopping bags'],
#  ['newspapers', 'beef'],
#  ['whole milk', 'pastry'],
#  ['citrus fruit'],
#  ['whole milk', 'shopping bags', 'brown bread'],
#  ['pastry', 'canned beer', 'whipped/sour cream'],
#  ['pastry'],
#  ['pastry', 'pip fruit'],
#  ['pip fruit', 'margarine'],
#  ['citrus fruit', 'margarine'],
#  ['curd'],
#  ['whole milk'],
#  ['yogurt', 'margarine'],
#  ['pastry', 'butter', 'curd', 'margarine'],
#  ['yogurt'],
#  ['whole milk', 'soda'],
#  ['soda'],
#  ['bottled water'],
#  ['other vegetables', 'whipped/sour cream'],
#  ['beef'],
#  ['whole milk', 'soda'],
#  ['bottled water'],
#  ['newspapers'],
#  ['whole milk', 'yogurt', 'newspapers'],
#  ['bottled beer'],
#  ['domestic eggs', 'pork'],
#  ['canned beer', 'curd'],
#  ['root vegetables', 'shopping bags'],
#  ['root vegetables', 'citrus fruit'],
#  ['shopping bags'],
#  ['brown bread'],
#  ['sausage', 'shopping bags'],
#  ['other vegetables', 'yogurt'],
#  ['yogurt', 'whipped/sour cream'],
#  ['root vegetables'],
#  ['other vegetables', 'butter'],
#  ['bottled water'],
#  ['other vegetables'],
#  ['other vegetables'],
#  ['rolls/buns', 'frankfurter'],
#  ['soda', 'brown bread'],
#  ['soda', 'brown bread'],
#  ['rolls/buns', 'newspapers'],
#  ['other vegetables', 'root vegetables', 'newspapers'],
#  ['whole milk', 'whipped/sour cream'],
#  ['bottled beer'],
#  ['yogurt'],
#  ['whole milk', 'pastry', 'butter'],
#  ['pip fruit', 'canned beer'],
#  ['rolls/buns', 'curd'],
#  ['whole milk'],
#  ['other vegetables'],
#  ['tropical fruit'],
#  ['soda', 'newspapers'],
#  ['citrus fruit', 'brown bread'],
#  ['other vegetables'],
#  ['tropical fruit', 'pastry'],
#  ['shopping bags', 'coffee'],
#  ['bottled water', 'citrus fruit'],
#  ['root vegetables'],
#  ['rolls/buns'],
#  ['rolls/buns', 'yogurt'],
#  ['soda', 'pork'],
#  ['whole milk', 'pip fruit'],
#  ['bottled beer'],
#  ['soda', 'yogurt'],
#  ['rolls/buns', 'margarine'],
#  ['shopping bags'],
#  ['sausage', 'pastry'],
#  ['rolls/buns', 'root vegetables', 'margarine'],
#  ['citrus fruit'],
#  ['rolls/buns', 'whipped/sour cream'],
#  ['root vegetables', 'newspapers', 'pork'],
#  ['whole milk'],
#  ['soda', 'citrus fruit'],
#  ['rolls/buns', 'shopping bags', 'frankfurter', 'margarine'],
#  ['soda'],
#  ['other vegetables', 'pastry', 'butter'],
#  ['domestic eggs'],
#  ['soda'],
#  ['coffee'],
#  ['frankfurter'],
#  ['yogurt', 'shopping bags', 'brown bread'],
#  ['whole milk'],
#  ['yogurt'],
#  ['root vegetables', 'bottled water', 'frankfurter'],
#  ['tropical fruit'],
#  ['soda', 'margarine'],
#  ['other vegetables', 'other vegetables', 'rolls/buns', 'shopping bags'],
#  ['whole milk', 'bottled beer'],
#  ['whole milk', 'soda'],
#  ['yogurt', 'pastry'],
#  ['rolls/buns', 'sausage'],
#  ['shopping bags', 'shopping bags', 'coffee'],
#  ['domestic eggs', 'curd'],
#  ['whole milk', 'pork'],
#  ['yogurt', 'pastry', 'brown bread'],
#  ['newspapers'],
#  ['other vegetables'],
#  ['soda', 'soda', 'sausage', 'shopping bags', 'butter'],
#  ['butter'],
#  ['whole milk', 'other vegetables'],
#  ['other vegetables', 'tropical fruit'],
#  ['other vegetables', 'beef'],
#  ['citrus fruit'],
#  ['tropical fruit', 'brown bread'],
#  ['root vegetables'],
#  ['whole milk', 'tropical fruit'],
#  ['citrus fruit'],
#  ['rolls/buns', 'fruit/vegetable juice'],
#  ['shopping bags'],
#  ['whole milk', 'other vegetables', 'other vegetables'],
#  ['canned beer'],
#  ['whole milk', 'root vegetables'],
#  ['citrus fruit'],
#  ['rolls/buns'],
#  ['pork'],
#  ['tropical fruit'],
#  ['rolls/buns', 'canned beer', 'brown bread'],
#  ['tropical fruit'],
#  ['other vegetables', 'frankfurter', 'curd'],
#  ['other vegetables', 'pip fruit'],
#  ['rolls/buns'],
#  ['whole milk', 'rolls/buns', 'soda'],
#  ['yogurt', 'tropical fruit'],
#  ['rolls/buns', 'soda'],
#  ['newspapers'],
#  ['other vegetables'],
#  ['brown bread'],
#  ['soda'],
#  ['whole milk', 'whole milk', 'soda'],
#  ['soda', 'pork'],
#  ['soda', 'whipped/sour cream'],
#  ['domestic eggs'],
#  ['root vegetables'],
#  ['canned beer'],
#  ['root vegetables', 'coffee'],
#  ['whole milk'],
#  ['domestic eggs', 'pork'],
#  ['soda', 'bottled beer'],
#  ['other vegetables', 'brown bread'],
#  ['root vegetables', 'tropical fruit'],
#  ['root vegetables', 'pip fruit'],
#  ['whole milk', 'bottled beer'],
#  ['soda', 'yogurt', 'yogurt'],
#  ['other vegetables'],
#  ['bottled water', 'shopping bags'],
#  ['curd'],
#  ['pork', 'margarine'],
#  ['whole milk', 'soda'],
#  ['whole milk', 'yogurt', 'sausage', 'shopping bags'],
#  ['yogurt', 'pork'],
#  ['other vegetables', 'soda'],
#  ['other vegetables', 'soda'],
#  ['tropical fruit', 'pork'],
#  ['soda', 'root vegetables'],
#  ['soda', 'yogurt', 'bottled beer'],
#  ['yogurt'],
#  ['other vegetables', 'fruit/vegetable juice'],
#  ['pip fruit'],
#  ['rolls/buns', 'bottled water'],
#  ['canned beer'],
#  ['pastry', 'pip fruit'],
#  ['curd'],
#  ['soda'],
#  ['domestic eggs', 'pork'],
#  ['soda'],
#  ['whole milk', 'rolls/buns'],
#  ['frankfurter'],
#  ['whole milk'],
#  ['butter'],
#  ['rolls/buns', 'tropical fruit', 'canned beer'],
#  ['whole milk', 'bottled beer'],
#  ['whole milk', 'sausage', 'citrus fruit', 'canned beer'],
#  ['rolls/buns'],
#  ['other vegetables', 'root vegetables'],
#  ['whole milk', 'yogurt', 'sausage'],
#  ['whole milk'],
#  ['frankfurter'],
#  ['other vegetables'],
#  ['beef', 'curd'],
#  ['whole milk', 'tropical fruit'],
#  ['whole milk'],
#  ['whole milk', 'bottled water'],
#  ['yogurt', 'citrus fruit'],
#  ['other vegetables', 'rolls/buns', 'rolls/buns', 'root vegetables', 'butter'],
#  ['domestic eggs'],
#  ['citrus fruit'],
#  ['soda', 'citrus fruit'],
#  ['butter'],
#  ['shopping bags'],
#  ['whole milk', 'root vegetables'],
#  ['tropical fruit', 'pip fruit'],
#  ['whole milk', 'yogurt'],
#  ['bottled beer', 'domestic eggs', 'beef', 'coffee'],
#  ['whole milk', 'other vegetables', 'yogurt'],
#  ['bottled beer', 'newspapers', 'beef'],
#  ['citrus fruit', 'canned beer'],
#  ['canned beer', 'fruit/vegetable juice'],
#  ['coffee'],
#  ['yogurt'],
#  ['bottled water', 'sausage'],
#  ['whole milk', 'bottled water', 'citrus fruit', 'newspapers', 'beef'],
#  ['whole milk', 'root vegetables'],
#  ['other vegetables'],
#  ['curd'],
#  ['whole milk'],
#  ['pork'],
#  ['beef'],
#  ['tropical fruit', 'bottled water'],
#  ['root vegetables', 'brown bread'],
#  ['domestic eggs', 'coffee'],
#  ['other vegetables', 'rolls/buns'],
#  ['frankfurter'],
#  ['whole milk', 'bottled beer'],
#  ['bottled water'],
#  ['bottled beer'],
#  ['soda', 'margarine'],
#  ['other vegetables', 'rolls/buns'],
#  ['soda'],
#  ['whipped/sour cream', 'newspapers'],
#  ['whole milk', 'other vegetables'],
#  ['whole milk',
#   'rolls/buns',
#   'soda',
#   'bottled water',
#   'bottled water',
#   'pork'],
#  ['citrus fruit', 'whipped/sour cream'],
#  ['shopping bags'],
#  ['pip fruit'],
#  ['whole milk'],
#  ['pip fruit', 'whipped/sour cream'],
#  ['whole milk', 'canned beer'],
#  ['brown bread'],
#  ['soda', 'whipped/sour cream'],
#  ['bottled water'],
#  ['other vegetables', 'soda'],
#  ['newspapers'],
#  ['rolls/buns', 'bottled beer', 'fruit/vegetable juice'],
#  ['rolls/buns'],
#  ['rolls/buns', 'margarine'],
#  ['citrus fruit'],
#  ['pip fruit', 'whipped/sour cream'],
#  ['rolls/buns', 'fruit/vegetable juice'],
#  ['root vegetables'],
#  ['whole milk', 'soda', 'yogurt', 'citrus fruit', 'shopping bags'],
#  ['yogurt', 'bottled water', 'butter', 'beef'],
#  ['other vegetables'],
#  ['citrus fruit', 'brown bread'],
#  ['whole milk', 'tropical fruit'],
#  ['domestic eggs'],
#  ['other vegetables', 'pastry'],
#  ['whole milk', 'soda'],
#  ['bottled water'],
#  ['other vegetables', 'tropical fruit'],
#  ['rolls/buns', 'canned beer', 'brown bread'],
#  ['tropical fruit', 'shopping bags'],
#  ['bottled water'],
#  ['coffee'],
#  ['other vegetables', 'pork'],
#  ['soda'],
#  ['citrus fruit'],
#  ['whole milk'],
#  ['whole milk', 'bottled beer'],
#  ['root vegetables', 'sausage'],
#  ['beef'],
#  ['whole milk', 'shopping bags'],
#  ['butter'],
#  ['rolls/buns'],
#  ['pip fruit'],
#  ['sausage', 'domestic eggs'],
#  ['other vegetables',
#   'sausage',
#   'canned beer',
#   'bottled beer',
#   'brown bread',
#   'butter'],
#  ['root vegetables', 'pastry', 'brown bread', 'butter'],
#  ['root vegetables'],
#  ['whole milk', 'newspapers', 'beef'],
#  ['canned beer', 'frankfurter'],
#  ['pip fruit'],
#  ['whole milk', 'beef'],
#  ['soda', 'butter'],
#  ['domestic eggs'],
#  ['whole milk', 'other vegetables'],
#  ['soda'],
#  ['soda', 'soda'],
#  ['citrus fruit', 'domestic eggs'],
#  ['other vegetables', 'shopping bags'],
#  ['bottled water'],
#  ['other vegetables', 'bottled beer'],
#  ['whole milk', 'rolls/buns', 'soda'],
#  ['bottled beer'],
#  ['tropical fruit'],
#  ['rolls/buns', 'soda', 'pip fruit'],
#  ['root vegetables', 'root vegetables'],
#  ['whipped/sour cream'],
#  ['other vegetables'],
#  ['bottled beer'],
#  ['soda', 'bottled water'],
#  ['root vegetables', 'canned beer'],
#  ['other vegetables', 'citrus fruit'],
#  ['pastry', 'brown bread'],
#  ['butter', 'fruit/vegetable juice'],
#  ['root vegetables', 'citrus fruit'],
#  ['soda', 'shopping bags'],
#  ['pip fruit'],
#  ['soda', 'pastry', 'butter', 'coffee'],
#  ['whole milk', 'bottled water'],
#  ['whole milk'],
#  ['shopping bags', 'butter'],
#  ['rolls/buns', 'bottled beer'],
#  ['pip fruit', 'shopping bags'],
#  ['newspapers', 'domestic eggs'],
#  ['sausage'],
#  ['whole milk', 'brown bread'],
#  ['pip fruit'],
#  ['whipped/sour cream', 'beef'],
#  ['yogurt', 'citrus fruit'],
#  ['yogurt',
#   'root vegetables',
#   'root vegetables',
#   'citrus fruit',
#   'whipped/sour cream'],
#  ['citrus fruit'],
#  ['other vegetables', 'newspapers'],
#  ['rolls/buns'],
#  ['sausage'],
#  ['whole milk', 'rolls/buns'],
#  ['bottled water'],
#  ['rolls/buns'],
#  ['root vegetables', 'citrus fruit'],
#  ['brown bread'],
#  ['coffee'],
#  ['whole milk'],
#  ['coffee'],
#  ['rolls/buns', 'yogurt'],
#  ['soda', 'root vegetables'],
#  ['yogurt'],
#  ['yogurt', 'root vegetables'],
#  ['pip fruit'],
#  ['soda'],
#  ['rolls/buns', 'pastry'],
#  ['root vegetables', 'bottled beer'],
#  ['whole milk'],
#  ['whole milk', 'yogurt', 'yogurt'],
#  ['whole milk'],
#  ['bottled water', 'curd'],
#  ['whole milk',
#   'other vegetables',
#   'rolls/buns',
#   'soda',
#   'soda',
#   'sausage',
#   'pastry'],
#  ['tropical fruit'],
#  ['sausage'],
#  ['whole milk', 'yogurt'],
#  ['shopping bags'],
#  ['whole milk', 'frankfurter'],
#  ['shopping bags'],
#  ['tropical fruit'],
#  ['yogurt', 'pork', 'beef'],
#  ['bottled water'],
#  ['rolls/buns'],
#  ['fruit/vegetable juice'],
#  ['yogurt', 'shopping bags'],
#  ['brown bread'],
#  ['sausage'],
#  ['butter', 'margarine'],
#  ['domestic eggs'],
#  ['rolls/buns', 'tropical fruit'],
#  ['whole milk'],
#  ['yogurt', 'frankfurter', 'butter'],
#  ['other vegetables'],
#  ['tropical fruit'],
#  ['other vegetables', 'root vegetables'],
#  ['domestic eggs', 'beef'],
#  ['tropical fruit'],
#  ['newspapers',
#   'newspapers',
#   'brown bread',
#   'pork',
#   'beef',
#   'beef',
#   'margarine'],
#  ['domestic eggs', 'fruit/vegetable juice'],
#  ['citrus fruit', 'bottled beer'],
#  ['yogurt', 'pip fruit'],
#  ['root vegetables', 'shopping bags'],
#  ['yogurt'],
#  ['other vegetables', 'pip fruit'],
#  ['whole milk',
#   'soda',
#   'root vegetables',
#   'tropical fruit',
#   'bottled water',
#   'pastry'],
#  ['canned beer', 'brown bread'],
#  ['citrus fruit'],
#  ['whole milk', 'pastry'],
#  ['bottled water', 'citrus fruit'],
#  ['whole milk'],
#  ['curd'],
#  ['whole milk', 'whole milk', 'yogurt', 'sausage', 'butter'],
#  ['citrus fruit', 'citrus fruit'],
#  ['rolls/buns', 'tropical fruit'],
#  ['whole milk', 'tropical fruit'],
#  ['pork'],
#  ['other vegetables', 'fruit/vegetable juice'],
#  ['canned beer', 'brown bread'],
#  ['rolls/buns', 'rolls/buns'],
#  ['canned beer', 'margarine'],
#  ['pastry'],
#  ['frankfurter'],
#  ['sausage'],
#  ['bottled water'],
#  ['canned beer', 'coffee'],
#  ['citrus fruit', 'butter'],
#  ['yogurt', 'citrus fruit'],
#  ['sausage'],
#  ['whole milk', 'curd'],
#  ['rolls/buns', 'pastry'],
#  ['other vegetables', 'bottled beer'],
#  ['brown bread'],
#  ['whole milk', 'whole milk', 'whole milk', 'shopping bags'],
#  ['soda'],
#  ['pastry'],
#  ['soda', 'citrus fruit', 'domestic eggs', 'beef'],
#  ['yogurt', 'whipped/sour cream'],
#  ['bottled beer'],
#  ['whipped/sour cream', 'newspapers'],
#  ['brown bread'],
#  ['beef'],
#  ['canned beer'],
#  ['soda', 'soda'],
#  ['whole milk', 'other vegetables'],
#  ['soda', 'canned beer'],
#  ['pastry', 'frankfurter'],
#  ['domestic eggs'],
#  ['yogurt', 'margarine'],
#  ['whipped/sour cream'],
#  ['soda'],
#  ['pork'],
#  ['root vegetables', 'sausage'],
#  ['canned beer'],
#  ['rolls/buns', 'bottled beer'],
#  ['bottled water', 'butter'],
#  ['whole milk'],
#  ['shopping bags', 'whipped/sour cream'],
#  ['rolls/buns',
#   'rolls/buns',
#   'soda',
#   'soda',
#   'canned beer',
#   'whipped/sour cream',
#   'margarine'],
#  ['other vegetables', 'rolls/buns'],
#  ['other vegetables'],
#  ['curd'],
#  ['yogurt', 'shopping bags', 'coffee'],
#  ['pastry', 'curd'],
#  ['root vegetables', 'bottled water', 'margarine'],
#  ['root vegetables'],
#  ['butter'],
#  ['canned beer', 'bottled beer'],
#  ['other vegetables', 'curd'],
#  ['shopping bags'],
#  ['sausage', 'sausage', 'bottled beer'],
#  ['other vegetables'],
#  ['soda', 'bottled water'],
#  ['pip fruit', 'newspapers'],
#  ['whole milk'],
#  ['rolls/buns'],
#  ['whole milk', 'other vegetables', 'soda', 'tropical fruit'],
#  ['other vegetables', 'citrus fruit'],
#  ['other vegetables', 'pork'],
#  ['frankfurter', 'margarine'],
#  ['soda'],
#  ['whole milk'],
#  ['tropical fruit', 'brown bread'],
#  ['yogurt', 'whipped/sour cream'],
#  ['sausage'],
#  ['yogurt', 'bottled water', 'bottled beer'],
#  ['whole milk', 'other vegetables', 'rolls/buns', 'sausage'],
#  ['soda', 'shopping bags'],
#  ['soda'],
#  ['whole milk'],
#  ['other vegetables'],
#  ['margarine'],
#  ['butter'],
#  ['bottled water', 'sausage', 'bottled beer'],
#  ['domestic eggs'],
#  ['sausage'],
#  ['tropical fruit', 'shopping bags'],
#  ['other vegetables', 'citrus fruit'],
#  ['soda'],
#  ['rolls/buns', 'bottled water', 'shopping bags'],
#  ['soda'],
#  ['shopping bags'],
#  ['other vegetables'],
#  ['rolls/buns', 'shopping bags'],
#  ['coffee'],
#  ['rolls/buns', 'tropical fruit'],
#  ['soda', 'soda', 'soda', 'shopping bags'],
#  ['yogurt', 'canned beer'],
#  ['yogurt', 'whipped/sour cream'],
#  ['tropical fruit'],
#  ['other vegetables'],
#  ['butter'],
#  ['other vegetables'],
#  ['beef', 'curd'],
#  ['whole milk', 'frankfurter'],
#  ['margarine', 'margarine'],
#  ['tropical fruit', 'pip fruit'],
#  ['citrus fruit'],
#  ['root vegetables'],
#  ['butter'],
#  ['soda', 'bottled beer'],
#  ['citrus fruit', 'coffee'],
#  ['other vegetables'],
#  ['canned beer', 'fruit/vegetable juice'],
#  ['pastry'],
#  ['whole milk', 'soda', 'pork'],
#  ['other vegetables'],
#  ['pastry'],
#  ['sausage'],
#  ['soda'],
#  ['coffee'],
#  ['other vegetables'],
#  ['butter'],
#  ['domestic eggs'],
#  ['sausage', 'coffee'],
#  ['rolls/buns', 'yogurt'],
#  ['rolls/buns', 'whipped/sour cream', 'fruit/vegetable juice'],
#  ['yogurt', 'coffee'],
#  ['root vegetables', 'pork'],
#  ['sausage'],
#  ['coffee'],
#  ['whole milk', 'shopping bags'],
#  ['fruit/vegetable juice'],
#  ['whole milk'],
#  ['sausage', 'curd'],
#  ['pip fruit', 'shopping bags'],
#  ['whole milk', 'domestic eggs'],
#  ['rolls/buns', 'rolls/buns'],
#  ['whole milk'],
#  ['other vegetables', 'citrus fruit'],
#  ['bottled beer'],
#  ['soda', 'yogurt', 'tropical fruit'],
#  ['other vegetables', 'tropical fruit', 'sausage'],
#  ['tropical fruit'],
#  ['bottled water', 'pastry'],
#  ['curd'],
#  ['tropical fruit', 'butter'],
#  ['other vegetables', 'domestic eggs'],
#  ['brown bread', 'pork'],
#  ['tropical fruit', 'shopping bags'],
#  ['yogurt', 'pork'],
#  ['root vegetables'],
#  ['whole milk', 'other vegetables', 'soda'],
#  ['other vegetables', 'citrus fruit', 'pastry', 'pip fruit', 'curd'],
#  ['other vegetables'],
#  ['whole milk', 'butter'],
#  ['other vegetables', 'brown bread', 'margarine'],
#  ['whole milk'],
#  ['rolls/buns'],
#  ['root vegetables', 'tropical fruit'],
#  ['whole milk', 'other vegetables'],
#  ['whole milk', 'other vegetables'],
#  ['pork'],
#  ['citrus fruit'],
#  ['whole milk'],
#  ['pastry', 'pork'],
#  ['rolls/buns'],
#  ['other vegetables', 'coffee'],
#  ['rolls/buns'],
#  ['citrus fruit', 'pastry'],
#  ['whole milk', 'other vegetables'],
#  ['citrus fruit'],
#  ['sausage'],
#  ['butter'],
#  ['root vegetables', 'butter'],
#  ['shopping bags', 'domestic eggs'],
#  ['curd'],
#  ['whole milk'],
#  ['whole milk', 'rolls/buns', 'sausage', 'bottled beer'],
#  ['yogurt'],
#  ['other vegetables', 'whipped/sour cream'],
#  ['whole milk', 'whole milk', 'yogurt'],
#  ['rolls/buns', 'sausage'],
#  ['shopping bags', 'frankfurter'],
#  ['brown bread', 'butter'],
#  ['other vegetables', 'bottled water', 'canned beer', 'canned beer', 'butter'],
#  ['root vegetables'],
#  ['root vegetables', 'newspapers'],
#  ['citrus fruit'],
#  ['soda'],
#  ['pastry'],
#  ['root vegetables'],
#  ['butter'],
#  ['rolls/buns', 'yogurt', 'tropical fruit', 'sausage'],
#  ['whole milk', 'whole milk', 'sausage', 'citrus fruit'],
#  ['rolls/buns'],
#  ['tropical fruit', 'newspapers', 'coffee'],
#  ['rolls/buns'],
#  ['rolls/buns'],
#  ['shopping bags'],
#  ['other vegetables'],
#  ['other vegetables', 'shopping bags'],
#  ['yogurt'],
#  ['soda', 'bottled water'],
#  ['whipped/sour cream'],
#  ['root vegetables'],
#  ['bottled water', 'butter'],
#  ['bottled water', 'pork'],
#  ['whole milk'],
#  ['bottled water', 'bottled water', 'newspapers'],
#  ['rolls/buns', 'margarine'],
#  ['rolls/buns', 'butter'],
#  ['yogurt'],
#  ['tropical fruit', 'bottled water'],
#  ['citrus fruit', 'shopping bags', 'butter'],
#  ['soda', 'pastry'],
#  ['whole milk', 'soda'],
#  ['bottled beer'],
#  ['root vegetables'],
#  ['yogurt'],
#  ['domestic eggs', 'pork'],
#  ['coffee'],
#  ['root vegetables'],
#  ['pip fruit', 'frankfurter'],
#  ['whipped/sour cream'],
#  ['other vegetables'],
#  ['whole milk',
#   'citrus fruit',
#   'pip fruit',
#   'whipped/sour cream',
#   'butter',
#   'margarine'],
#  ['whole milk', 'rolls/buns', 'citrus fruit'],
#  ['whole milk'],
#  ['root vegetables'],
#  ['other vegetables', 'canned beer', 'brown bread'],
#  ['rolls/buns'],
#  ['yogurt'],
#  ['whole milk',
#   'other vegetables',
#   'yogurt',
#   'sausage',
#   'frankfurter',
#   'margarine'],
#  ['margarine'],
#  ['sausage', 'whipped/sour cream'],
#  ['whole milk', 'rolls/buns'],
#  ['domestic eggs', 'fruit/vegetable juice'],
#  ['rolls/buns', 'tropical fruit', 'citrus fruit', 'domestic eggs'],
#  ['rolls/buns'],
#  ['pork'],
#  ['whole milk'],
#  ['tropical fruit', 'pip fruit'],
#  ['shopping bags', 'canned beer'],
#  ['whole milk'],
#  ['whole milk'],
#  ['other vegetables', 'soda', 'root vegetables'],
#  ['domestic eggs'],
#  ['whipped/sour cream'],
#  ['bottled water', 'sausage'],
#  ['frankfurter'],
#  ['other vegetables', 'soda'],
#  ['root vegetables', 'root vegetables', 'pip fruit'],
#  ['bottled beer'],
#  ['tropical fruit'],
#  ['other vegetables', 'yogurt'],
#  ['sausage'],
#  ['domestic eggs'],
#  ['yogurt'],
#  ['soda'],
#  ['bottled beer'],
#  ['rolls/buns', 'pastry'],
#  ['whole milk', 'other vegetables', 'bottled beer'],
#  ['rolls/buns', 'yogurt'],
#  ['canned beer'],
#  ['yogurt'],
#  ['soda', 'sausage'],
#  ['pip fruit'],
#  ['whipped/sour cream'],
#  ['rolls/buns', 'citrus fruit', 'butter'],
#  ['root vegetables', 'fruit/vegetable juice'],
#  ['root vegetables', 'bottled water'],
#  ['yogurt', 'shopping bags'],
#  ['tropical fruit', 'pastry'],
#  ['whole milk', 'pastry'],
#  ['whole milk', 'canned beer', 'bottled beer'],
#  ['pip fruit'],
#  ['rolls/buns', 'yogurt', 'margarine'],
#  ['whole milk', 'frankfurter'],
#  ['rolls/buns', 'whipped/sour cream'],
#  ['other vegetables'],
#  ['sausage'],
#  ['root vegetables'],
#  ['whole milk',
#   'other vegetables',
#   'yogurt',
#   'tropical fruit',
#   'citrus fruit',
#   'pork'],
#  ['yogurt'],
#  ['whole milk', 'rolls/buns', 'yogurt', 'pork'],
#  ...]

# %% [markdown]
# ## Frecuencia Sup = 0.05
#
# Repetimos todo el proceso anterior, pero en esta ocasión con un soporte mínimo de 0.05

# %%
Freq_minsup5 = Frecuencia[Frecuencia["Soporte"] >= 0.05]
Freq_minsup5 = Freq_minsup5.sort_values(by = "Frecuencia", ascending=False)
Freq_minsup5
# Out:
#             Elementos  Frecuencia   Soporte
# 68         whole milk        2502  0.167212
# 133  other vegetables        1898  0.126846
# 23         rolls/buns        1716  0.114683
# 144              soda        1514  0.101183
# 56             yogurt        1334  0.089153
# 134   root vegetables        1071  0.071577
# 165    tropical fruit        1032  0.068970
# 114     bottled water         933  0.062354
# 98            sausage         924  0.061752
# 123      citrus fruit         812  0.054267
# 154            pastry         785  0.052463

# %%
print("Elementos con soporte mínimo = 0.05: ", len(Freq_minsup5))
# Out:
# Elementos con soporte mínimo = 0.05:  11

# %%
trans_list = []
for k in range(len(Transacciones)):
    trans_frec = []
    for j in range(len(Freq_minsup5)): 
        for i in range(len(Transacciones['Transacciones'][k].replace("'", "").split(", "))):
            Transaccions = Transacciones['Transacciones'][k].replace("'", "")
            if Transaccions.split(", ")[i].replace(" ", "") == Freq_minsup5['Elementos'].values[j].replace(" ", ""):
                items = str(Freq_minsup5['Elementos'].values[j])
                trans_frec.append(items)

    trans_list.append(list(trans_frec))

# %%
Transacciones_final = []
for i in range(len(trans_list)):
    if trans_list[i] != []:
        Transacciones_final.append(trans_list[i])

# %%
print('Número de transacciones frecuentes con Soporte Mínimo de 0.03: ',len(Transacciones_final))
# Out:
# Número de transacciones frecuentes con Soporte Mínimo de 0.03:  10174

# %% [markdown]
# ### Obtenemos nuestras transacciones de productos frecuentes dentro de nuestro soporte mínimo

# %%
Transacciones_final
# Out:
# [['sausage'],
#  ['whole milk', 'pastry'],
#  ['soda'],
#  ['whole milk', 'yogurt', 'sausage'],
#  ['whole milk', 'soda'],
#  ['soda'],
#  ['whole milk', 'rolls/buns', 'sausage'],
#  ['other vegetables'],
#  ['tropical fruit'],
#  ['whole milk'],
#  ['root vegetables'],
#  ['rolls/buns', 'sausage'],
#  ['rolls/buns', 'rolls/buns'],
#  ['rolls/buns'],
#  ['other vegetables'],
#  ['whole milk', 'root vegetables', 'pastry'],
#  ['other vegetables'],
#  ['whole milk', 'tropical fruit'],
#  ['whole milk', 'rolls/buns'],
#  ['rolls/buns', 'rolls/buns'],
#  ['whole milk'],
#  ['whole milk', 'rolls/buns'],
#  ['rolls/buns', 'bottled water'],
#  ['soda', 'yogurt', 'yogurt', 'root vegetables', 'tropical fruit'],
#  ['yogurt'],
#  ['yogurt', 'tropical fruit'],
#  ['pastry'],
#  ['rolls/buns'],
#  ['bottled water'],
#  ['bottled water'],
#  ['whole milk', 'other vegetables', 'yogurt'],
#  ['pastry'],
#  ['rolls/buns', 'bottled water', 'citrus fruit'],
#  ['yogurt'],
#  ['rolls/buns', 'root vegetables', 'tropical fruit'],
#  ['whole milk'],
#  ['whole milk'],
#  ['bottled water'],
#  ['other vegetables'],
#  ['tropical fruit'],
#  ['whole milk'],
#  ['root vegetables'],
#  ['whole milk', 'yogurt', 'sausage'],
#  ['whole milk', 'rolls/buns'],
#  ['whole milk', 'citrus fruit'],
#  ['rolls/buns'],
#  ['rolls/buns'],
#  ['other vegetables', 'root vegetables'],
#  ['yogurt'],
#  ['soda'],
#  ['other vegetables', 'rolls/buns'],
#  ['root vegetables'],
#  ['yogurt'],
#  ['rolls/buns'],
#  ['rolls/buns'],
#  ['yogurt', 'tropical fruit'],
#  ['sausage'],
#  ['whole milk'],
#  ['rolls/buns', 'root vegetables'],
#  ['yogurt'],
#  ['soda'],
#  ['sausage'],
#  ['other vegetables', 'root vegetables', 'tropical fruit'],
#  ['rolls/buns', 'sausage'],
#  ['yogurt', 'citrus fruit'],
#  ['root vegetables'],
#  ['root vegetables', 'root vegetables'],
#  ['rolls/buns'],
#  ['whole milk'],
#  ['rolls/buns', 'bottled water'],
#  ['root vegetables'],
#  ['rolls/buns'],
#  ['rolls/buns', 'bottled water'],
#  ['soda'],
#  ['other vegetables', 'other vegetables'],
#  ['other vegetables', 'soda'],
#  ['whole milk', 'pastry'],
#  ['yogurt', 'root vegetables'],
#  ['pastry'],
#  ['rolls/buns', 'soda', 'tropical fruit'],
#  ['rolls/buns', 'sausage'],
#  ['bottled water'],
#  ['yogurt'],
#  ['tropical fruit'],
#  ['sausage'],
#  ['whole milk', 'rolls/buns', 'yogurt', 'yogurt'],
#  ['whole milk'],
#  ['whole milk'],
#  ['yogurt'],
#  ['citrus fruit'],
#  ['rolls/buns', 'tropical fruit'],
#  ['whole milk'],
#  ['whole milk', 'sausage'],
#  ['other vegetables'],
#  ['rolls/buns'],
#  ['rolls/buns', 'yogurt'],
#  ['root vegetables'],
#  ['whole milk', 'rolls/buns'],
#  ['tropical fruit'],
#  ['whole milk', 'tropical fruit'],
#  ['yogurt'],
#  ['bottled water', 'citrus fruit'],
#  ['whole milk', 'other vegetables'],
#  ['whole milk', 'rolls/buns', 'citrus fruit'],
#  ['whole milk'],
#  ['tropical fruit'],
#  ['root vegetables'],
#  ['other vegetables', 'tropical fruit'],
#  ['yogurt', 'yogurt', 'root vegetables'],
#  ['whole milk', 'pastry'],
#  ['bottled water'],
#  ['soda'],
#  ['soda'],
#  ['rolls/buns', 'tropical fruit'],
#  ['whole milk', 'rolls/buns', 'soda'],
#  ['whole milk'],
#  ['whole milk'],
#  ['other vegetables'],
#  ['yogurt'],
#  ['yogurt'],
#  ['other vegetables', 'rolls/buns', 'soda'],
#  ['tropical fruit'],
#  ['other vegetables', 'tropical fruit'],
#  ['whole milk', 'soda'],
#  ['root vegetables'],
#  ['soda'],
#  ['other vegetables', 'yogurt'],
#  ['yogurt', 'yogurt'],
#  ['bottled water'],
#  ['soda', 'soda'],
#  ['whole milk'],
#  ['rolls/buns'],
#  ['whole milk', 'other vegetables'],
#  ['pastry'],
#  ['soda'],
#  ['other vegetables'],
#  ['citrus fruit'],
#  ['soda', 'yogurt', 'bottled water'],
#  ['whole milk'],
#  ['other vegetables'],
#  ['tropical fruit'],
#  ['soda', 'soda'],
#  ['yogurt', 'root vegetables'],
#  ['other vegetables', 'root vegetables'],
#  ['other vegetables'],
#  ['bottled water', 'sausage'],
#  ['sausage'],
#  ['soda'],
#  ['whole milk', 'root vegetables', 'tropical fruit'],
#  ['whole milk'],
#  ['whole milk', 'other vegetables', 'tropical fruit'],
#  ['whole milk', 'other vegetables', 'yogurt'],
#  ['rolls/buns'],
#  ['whole milk', 'citrus fruit'],
#  ['rolls/buns'],
#  ['other vegetables', 'root vegetables'],
#  ['whole milk', 'root vegetables'],
#  ['tropical fruit'],
#  ['soda'],
#  ['whole milk', 'tropical fruit'],
#  ['rolls/buns', 'tropical fruit'],
#  ['root vegetables'],
#  ['whole milk', 'other vegetables'],
#  ['rolls/buns', 'tropical fruit'],
#  ['whole milk', 'tropical fruit'],
#  ['soda', 'yogurt'],
#  ['tropical fruit'],
#  ['rolls/buns'],
#  ['citrus fruit'],
#  ['yogurt'],
#  ['other vegetables'],
#  ['yogurt', 'bottled water'],
#  ['bottled water', 'citrus fruit'],
#  ['rolls/buns'],
#  ['sausage'],
#  ['bottled water', 'sausage'],
#  ['whole milk', 'whole milk'],
#  ['bottled water'],
#  ['pastry'],
#  ['other vegetables'],
#  ['rolls/buns', 'soda'],
#  ['soda', 'tropical fruit'],
#  ['rolls/buns', 'root vegetables'],
#  ['rolls/buns'],
#  ['soda'],
#  ['bottled water'],
#  ['rolls/buns'],
#  ['soda'],
#  ['root vegetables'],
#  ['whole milk', 'other vegetables', 'pastry'],
#  ['whole milk', 'tropical fruit'],
#  ['yogurt'],
#  ['yogurt', 'tropical fruit'],
#  ['bottled water'],
#  ['other vegetables'],
#  ['soda'],
#  ['whole milk'],
#  ['other vegetables'],
#  ['root vegetables', 'citrus fruit'],
#  ['yogurt'],
#  ['other vegetables', 'soda'],
#  ['rolls/buns', 'citrus fruit'],
#  ['rolls/buns', 'soda'],
#  ['other vegetables', 'soda'],
#  ['soda'],
#  ['sausage'],
#  ['whole milk', 'other vegetables'],
#  ['whole milk', 'whole milk'],
#  ['sausage'],
#  ['yogurt'],
#  ['whole milk'],
#  ['other vegetables', 'tropical fruit'],
#  ['yogurt'],
#  ['yogurt'],
#  ['whole milk'],
#  ['yogurt', 'sausage', 'pastry'],
#  ['other vegetables'],
#  ['rolls/buns', 'bottled water', 'sausage'],
#  ['yogurt'],
#  ['other vegetables', 'soda', 'root vegetables'],
#  ['whole milk'],
#  ['root vegetables', 'tropical fruit', 'sausage'],
#  ['whole milk', 'sausage'],
#  ['other vegetables'],
#  ['soda', 'tropical fruit'],
#  ['whole milk'],
#  ['bottled water'],
#  ['yogurt'],
#  ['root vegetables'],
#  ['whole milk', 'soda', 'tropical fruit'],
#  ['whole milk', 'sausage'],
#  ['whole milk'],
#  ['bottled water'],
#  ['tropical fruit'],
#  ['other vegetables'],
#  ['rolls/buns'],
#  ['root vegetables', 'bottled water'],
#  ['rolls/buns'],
#  ['whole milk', 'yogurt', 'tropical fruit', 'citrus fruit'],
#  ['citrus fruit'],
#  ['root vegetables'],
#  ['whole milk', 'yogurt'],
#  ['soda'],
#  ['whole milk'],
#  ['other vegetables', 'rolls/buns'],
#  ['yogurt'],
#  ['other vegetables'],
#  ['root vegetables'],
#  ['yogurt'],
#  ['pastry'],
#  ['yogurt'],
#  ['other vegetables', 'rolls/buns', 'yogurt'],
#  ['yogurt', 'root vegetables'],
#  ['whole milk'],
#  ['other vegetables'],
#  ['whole milk', 'yogurt', 'tropical fruit', 'bottled water'],
#  ['citrus fruit'],
#  ['rolls/buns'],
#  ['rolls/buns'],
#  ['rolls/buns'],
#  ['whole milk', 'pastry'],
#  ['citrus fruit'],
#  ['whole milk'],
#  ['pastry'],
#  ['pastry'],
#  ['pastry'],
#  ['citrus fruit'],
#  ['whole milk'],
#  ['yogurt'],
#  ['pastry'],
#  ['yogurt'],
#  ['whole milk', 'soda'],
#  ['soda'],
#  ['bottled water'],
#  ['other vegetables'],
#  ['whole milk', 'soda'],
#  ['bottled water'],
#  ['whole milk', 'yogurt'],
#  ['root vegetables'],
#  ['root vegetables', 'citrus fruit'],
#  ['sausage'],
#  ['other vegetables', 'yogurt'],
#  ['yogurt'],
#  ['root vegetables'],
#  ['other vegetables'],
#  ['bottled water'],
#  ['other vegetables'],
#  ['other vegetables'],
#  ['rolls/buns'],
#  ['soda'],
#  ['soda'],
#  ['rolls/buns'],
#  ['other vegetables', 'root vegetables'],
#  ['whole milk'],
#  ['yogurt'],
#  ['whole milk', 'pastry'],
#  ['rolls/buns'],
#  ['whole milk'],
#  ['other vegetables'],
#  ['tropical fruit'],
#  ['soda'],
#  ['citrus fruit'],
#  ['other vegetables'],
#  ['tropical fruit', 'pastry'],
#  ['bottled water', 'citrus fruit'],
#  ['root vegetables'],
#  ['rolls/buns'],
#  ['rolls/buns', 'yogurt'],
#  ['soda'],
#  ['whole milk'],
#  ['soda', 'yogurt'],
#  ['rolls/buns'],
#  ['sausage', 'pastry'],
#  ['rolls/buns', 'root vegetables'],
#  ['citrus fruit'],
#  ['rolls/buns'],
#  ['root vegetables'],
#  ['whole milk'],
#  ['soda', 'citrus fruit'],
#  ['rolls/buns'],
#  ['soda'],
#  ['other vegetables', 'pastry'],
#  ['soda'],
#  ['yogurt'],
#  ['whole milk'],
#  ['yogurt'],
#  ['root vegetables', 'bottled water'],
#  ['tropical fruit'],
#  ['soda'],
#  ['other vegetables', 'other vegetables', 'rolls/buns'],
#  ['whole milk'],
#  ['whole milk', 'soda'],
#  ['yogurt', 'pastry'],
#  ['rolls/buns', 'sausage'],
#  ['whole milk'],
#  ['yogurt', 'pastry'],
#  ['other vegetables'],
#  ['soda', 'soda', 'sausage'],
#  ['whole milk', 'other vegetables'],
#  ['other vegetables', 'tropical fruit'],
#  ['other vegetables'],
#  ['citrus fruit'],
#  ['tropical fruit'],
#  ['root vegetables'],
#  ['whole milk', 'tropical fruit'],
#  ['citrus fruit'],
#  ['rolls/buns'],
#  ['whole milk', 'other vegetables', 'other vegetables'],
#  ['whole milk', 'root vegetables'],
#  ['citrus fruit'],
#  ['rolls/buns'],
#  ['tropical fruit'],
#  ['rolls/buns'],
#  ['tropical fruit'],
#  ['other vegetables'],
#  ['other vegetables'],
#  ['rolls/buns'],
#  ['whole milk', 'rolls/buns', 'soda'],
#  ['yogurt', 'tropical fruit'],
#  ['rolls/buns', 'soda'],
#  ['other vegetables'],
#  ['soda'],
#  ['whole milk', 'whole milk', 'soda'],
#  ['soda'],
#  ['soda'],
#  ['root vegetables'],
#  ['root vegetables'],
#  ['whole milk'],
#  ['soda'],
#  ['other vegetables'],
#  ['root vegetables', 'tropical fruit'],
#  ['root vegetables'],
#  ['whole milk'],
#  ['soda', 'yogurt', 'yogurt'],
#  ['other vegetables'],
#  ['bottled water'],
#  ['whole milk', 'soda'],
#  ['whole milk', 'yogurt', 'sausage'],
#  ['yogurt'],
#  ['other vegetables', 'soda'],
#  ['other vegetables', 'soda'],
#  ['tropical fruit'],
#  ['soda', 'root vegetables'],
#  ['soda', 'yogurt'],
#  ['yogurt'],
#  ['other vegetables'],
#  ['rolls/buns', 'bottled water'],
#  ['pastry'],
#  ['soda'],
#  ['soda'],
#  ['whole milk', 'rolls/buns'],
#  ['whole milk'],
#  ['rolls/buns', 'tropical fruit'],
#  ['whole milk'],
#  ['whole milk', 'sausage', 'citrus fruit'],
#  ['rolls/buns'],
#  ['other vegetables', 'root vegetables'],
#  ['whole milk', 'yogurt', 'sausage'],
#  ['whole milk'],
#  ['other vegetables'],
#  ['whole milk', 'tropical fruit'],
#  ['whole milk'],
#  ['whole milk', 'bottled water'],
#  ['yogurt', 'citrus fruit'],
#  ['other vegetables', 'rolls/buns', 'rolls/buns', 'root vegetables'],
#  ['citrus fruit'],
#  ['soda', 'citrus fruit'],
#  ['whole milk', 'root vegetables'],
#  ['tropical fruit'],
#  ['whole milk', 'yogurt'],
#  ['whole milk', 'other vegetables', 'yogurt'],
#  ['citrus fruit'],
#  ['yogurt'],
#  ['bottled water', 'sausage'],
#  ['whole milk', 'bottled water', 'citrus fruit'],
#  ['whole milk', 'root vegetables'],
#  ['other vegetables'],
#  ['whole milk'],
#  ['tropical fruit', 'bottled water'],
#  ['root vegetables'],
#  ['other vegetables', 'rolls/buns'],
#  ['whole milk'],
#  ['bottled water'],
#  ['soda'],
#  ['other vegetables', 'rolls/buns'],
#  ['soda'],
#  ['whole milk', 'other vegetables'],
#  ['whole milk', 'rolls/buns', 'soda', 'bottled water', 'bottled water'],
#  ['citrus fruit'],
#  ['whole milk'],
#  ['whole milk'],
#  ['soda'],
#  ['bottled water'],
#  ['other vegetables', 'soda'],
#  ['rolls/buns'],
#  ['rolls/buns'],
#  ['rolls/buns'],
#  ['citrus fruit'],
#  ['rolls/buns'],
#  ['root vegetables'],
#  ['whole milk', 'soda', 'yogurt', 'citrus fruit'],
#  ['yogurt', 'bottled water'],
#  ['other vegetables'],
#  ['citrus fruit'],
#  ['whole milk', 'tropical fruit'],
#  ['other vegetables', 'pastry'],
#  ['whole milk', 'soda'],
#  ['bottled water'],
#  ['other vegetables', 'tropical fruit'],
#  ['rolls/buns'],
#  ['tropical fruit'],
#  ['bottled water'],
#  ['other vegetables'],
#  ['soda'],
#  ['citrus fruit'],
#  ['whole milk'],
#  ['whole milk'],
#  ['root vegetables', 'sausage'],
#  ['whole milk'],
#  ['rolls/buns'],
#  ['sausage'],
#  ['other vegetables', 'sausage'],
#  ['root vegetables', 'pastry'],
#  ['root vegetables'],
#  ['whole milk'],
#  ['whole milk'],
#  ['soda'],
#  ['whole milk', 'other vegetables'],
#  ['soda'],
#  ['soda', 'soda'],
#  ['citrus fruit'],
#  ['other vegetables'],
#  ['bottled water'],
#  ['other vegetables'],
#  ['whole milk', 'rolls/buns', 'soda'],
#  ['tropical fruit'],
#  ['rolls/buns', 'soda'],
#  ['root vegetables', 'root vegetables'],
#  ['other vegetables'],
#  ['soda', 'bottled water'],
#  ['root vegetables'],
#  ['other vegetables', 'citrus fruit'],
#  ['pastry'],
#  ['root vegetables', 'citrus fruit'],
#  ['soda'],
#  ['soda', 'pastry'],
#  ['whole milk', 'bottled water'],
#  ['whole milk'],
#  ['rolls/buns'],
#  ['sausage'],
#  ['whole milk'],
#  ['yogurt', 'citrus fruit'],
#  ['yogurt', 'root vegetables', 'root vegetables', 'citrus fruit'],
#  ['citrus fruit'],
#  ['other vegetables'],
#  ['rolls/buns'],
#  ['sausage'],
#  ['whole milk', 'rolls/buns'],
#  ['bottled water'],
#  ['rolls/buns'],
#  ['root vegetables', 'citrus fruit'],
#  ['whole milk'],
#  ['rolls/buns', 'yogurt'],
#  ['soda', 'root vegetables'],
#  ['yogurt'],
#  ['yogurt', 'root vegetables'],
#  ['soda'],
#  ['rolls/buns', 'pastry'],
#  ['root vegetables'],
#  ['whole milk'],
#  ['whole milk', 'yogurt', 'yogurt'],
#  ['whole milk'],
#  ['bottled water'],
#  ['whole milk',
#   'other vegetables',
#   'rolls/buns',
#   'soda',
#   'soda',
#   'sausage',
#   'pastry'],
#  ['tropical fruit'],
#  ['sausage'],
#  ['whole milk', 'yogurt'],
#  ['whole milk'],
#  ['tropical fruit'],
#  ['yogurt'],
#  ['bottled water'],
#  ['rolls/buns'],
#  ['yogurt'],
#  ['sausage'],
#  ['rolls/buns', 'tropical fruit'],
#  ['whole milk'],
#  ['yogurt'],
#  ['other vegetables'],
#  ['tropical fruit'],
#  ['other vegetables', 'root vegetables'],
#  ['tropical fruit'],
#  ['citrus fruit'],
#  ['yogurt'],
#  ['root vegetables'],
#  ['yogurt'],
#  ['other vegetables'],
#  ['whole milk',
#   'soda',
#   'root vegetables',
#   'tropical fruit',
#   'bottled water',
#   'pastry'],
#  ['citrus fruit'],
#  ['whole milk', 'pastry'],
#  ['bottled water', 'citrus fruit'],
#  ['whole milk'],
#  ['whole milk', 'whole milk', 'yogurt', 'sausage'],
#  ['citrus fruit', 'citrus fruit'],
#  ['rolls/buns', 'tropical fruit'],
#  ['whole milk', 'tropical fruit'],
#  ['other vegetables'],
#  ['rolls/buns', 'rolls/buns'],
#  ['pastry'],
#  ['sausage'],
#  ['bottled water'],
#  ['citrus fruit'],
#  ['yogurt', 'citrus fruit'],
#  ['sausage'],
#  ['whole milk'],
#  ['rolls/buns', 'pastry'],
#  ['other vegetables'],
#  ['whole milk', 'whole milk', 'whole milk'],
#  ['soda'],
#  ['pastry'],
#  ['soda', 'citrus fruit'],
#  ['yogurt'],
#  ['soda', 'soda'],
#  ['whole milk', 'other vegetables'],
#  ['soda'],
#  ['pastry'],
#  ['yogurt'],
#  ['soda'],
#  ['root vegetables', 'sausage'],
#  ['rolls/buns'],
#  ['bottled water'],
#  ['whole milk'],
#  ['rolls/buns', 'rolls/buns', 'soda', 'soda'],
#  ['other vegetables', 'rolls/buns'],
#  ['other vegetables'],
#  ['yogurt'],
#  ['pastry'],
#  ['root vegetables', 'bottled water'],
#  ['root vegetables'],
#  ['other vegetables'],
#  ['sausage', 'sausage'],
#  ['other vegetables'],
#  ['soda', 'bottled water'],
#  ['whole milk'],
#  ['rolls/buns'],
#  ['whole milk', 'other vegetables', 'soda', 'tropical fruit'],
#  ['other vegetables', 'citrus fruit'],
#  ['other vegetables'],
#  ['soda'],
#  ['whole milk'],
#  ['tropical fruit'],
#  ['yogurt'],
#  ['sausage'],
#  ['yogurt', 'bottled water'],
#  ['whole milk', 'other vegetables', 'rolls/buns', 'sausage'],
#  ['soda'],
#  ['soda'],
#  ['whole milk'],
#  ['other vegetables'],
#  ['bottled water', 'sausage'],
#  ['sausage'],
#  ['tropical fruit'],
#  ['other vegetables', 'citrus fruit'],
#  ['soda'],
#  ['rolls/buns', 'bottled water'],
#  ['soda'],
#  ['other vegetables'],
#  ['rolls/buns'],
#  ['rolls/buns', 'tropical fruit'],
#  ['soda', 'soda', 'soda'],
#  ['yogurt'],
#  ['yogurt'],
#  ['tropical fruit'],
#  ['other vegetables'],
#  ['other vegetables'],
#  ['whole milk'],
#  ['tropical fruit'],
#  ['citrus fruit'],
#  ['root vegetables'],
#  ['soda'],
#  ['citrus fruit'],
#  ['other vegetables'],
#  ['pastry'],
#  ['whole milk', 'soda'],
#  ['other vegetables'],
#  ['pastry'],
#  ['sausage'],
#  ['soda'],
#  ['other vegetables'],
#  ['sausage'],
#  ['rolls/buns', 'yogurt'],
#  ['rolls/buns'],
#  ['yogurt'],
#  ['root vegetables'],
#  ['sausage'],
#  ['whole milk'],
#  ['whole milk'],
#  ['sausage'],
#  ['whole milk'],
#  ['rolls/buns', 'rolls/buns'],
#  ['whole milk'],
#  ['other vegetables', 'citrus fruit'],
#  ['soda', 'yogurt', 'tropical fruit'],
#  ['other vegetables', 'tropical fruit', 'sausage'],
#  ['tropical fruit'],
#  ['bottled water', 'pastry'],
#  ['tropical fruit'],
#  ['other vegetables'],
#  ['tropical fruit'],
#  ['yogurt'],
#  ['root vegetables'],
#  ['whole milk', 'other vegetables', 'soda'],
#  ['other vegetables', 'citrus fruit', 'pastry'],
#  ['other vegetables'],
#  ['whole milk'],
#  ['other vegetables'],
#  ['whole milk'],
#  ['rolls/buns'],
#  ['root vegetables', 'tropical fruit'],
#  ['whole milk', 'other vegetables'],
#  ['whole milk', 'other vegetables'],
#  ['citrus fruit'],
#  ['whole milk'],
#  ['pastry'],
#  ['rolls/buns'],
#  ['other vegetables'],
#  ['rolls/buns'],
#  ['citrus fruit', 'pastry'],
#  ['whole milk', 'other vegetables'],
#  ['citrus fruit'],
#  ['sausage'],
#  ['root vegetables'],
#  ['whole milk'],
#  ['whole milk', 'rolls/buns', 'sausage'],
#  ['yogurt'],
#  ['other vegetables'],
#  ['whole milk', 'whole milk', 'yogurt'],
#  ['rolls/buns', 'sausage'],
#  ['other vegetables', 'bottled water'],
#  ['root vegetables'],
#  ['root vegetables'],
#  ['citrus fruit'],
#  ['soda'],
#  ['pastry'],
#  ['root vegetables'],
#  ['rolls/buns', 'yogurt', 'tropical fruit', 'sausage'],
#  ['whole milk', 'whole milk', 'sausage', 'citrus fruit'],
#  ['rolls/buns'],
#  ['tropical fruit'],
#  ['rolls/buns'],
#  ['rolls/buns'],
#  ['other vegetables'],
#  ['other vegetables'],
#  ['yogurt'],
#  ['soda', 'bottled water'],
#  ['root vegetables'],
#  ['bottled water'],
#  ['bottled water'],
#  ['whole milk'],
#  ['bottled water', 'bottled water'],
#  ['rolls/buns'],
#  ['rolls/buns'],
#  ['yogurt'],
#  ['tropical fruit', 'bottled water'],
#  ['citrus fruit'],
#  ['soda', 'pastry'],
#  ['whole milk', 'soda'],
#  ['root vegetables'],
#  ['yogurt'],
#  ['root vegetables'],
#  ['other vegetables'],
#  ['whole milk', 'citrus fruit'],
#  ['whole milk', 'rolls/buns', 'citrus fruit'],
#  ['whole milk'],
#  ['root vegetables'],
#  ['other vegetables'],
#  ['rolls/buns'],
#  ['yogurt'],
#  ['whole milk', 'other vegetables', 'yogurt', 'sausage'],
#  ['sausage'],
#  ['whole milk', 'rolls/buns'],
#  ['rolls/buns', 'tropical fruit', 'citrus fruit'],
#  ['rolls/buns'],
#  ['whole milk'],
#  ['tropical fruit'],
#  ['whole milk'],
#  ['whole milk'],
#  ['other vegetables', 'soda', 'root vegetables'],
#  ['bottled water', 'sausage'],
#  ['other vegetables', 'soda'],
#  ['root vegetables', 'root vegetables'],
#  ['tropical fruit'],
#  ['other vegetables', 'yogurt'],
#  ['sausage'],
#  ['yogurt'],
#  ['soda'],
#  ['rolls/buns', 'pastry'],
#  ['whole milk', 'other vegetables'],
#  ['rolls/buns', 'yogurt'],
#  ['yogurt'],
#  ['soda', 'sausage'],
#  ['rolls/buns', 'citrus fruit'],
#  ['root vegetables'],
#  ['root vegetables', 'bottled water'],
#  ['yogurt'],
#  ['tropical fruit', 'pastry'],
#  ['whole milk', 'pastry'],
#  ['whole milk'],
#  ['rolls/buns', 'yogurt'],
#  ['whole milk'],
#  ['rolls/buns'],
#  ['other vegetables'],
#  ['sausage'],
#  ['root vegetables'],
#  ['whole milk',
#   'other vegetables',
#   'yogurt',
#   'tropical fruit',
#   'citrus fruit'],
#  ['yogurt'],
#  ['whole milk', 'rolls/buns', 'yogurt'],
#  ['whole milk', 'rolls/buns'],
#  ['whole milk'],
#  ['pastry'],
#  ['sausage', 'pastry'],
#  ['other vegetables', 'rolls/buns'],
#  ['root vegetables'],
#  ['whole milk'],
#  ['pastry'],
#  ['sausage'],
#  ['pastry'],
#  ['tropical fruit'],
#  ['rolls/buns'],
#  ['other vegetables', 'rolls/buns'],
#  ['other vegetables'],
#  ['rolls/buns', 'tropical fruit'],
#  ['other vegetables'],
#  ['rolls/buns'],
#  ['tropical fruit'],
#  ['rolls/buns'],
#  ['rolls/buns', 'sausage'],
#  ['other vegetables', 'citrus fruit'],
#  ['pastry'],
#  ['yogurt'],
#  ['soda'],
#  ['pastry'],
#  ['root vegetables'],
#  ['root vegetables'],
#  ['soda', 'citrus fruit', 'citrus fruit'],
#  ['soda'],
#  ['rolls/buns'],
#  ['citrus fruit'],
#  ['whole milk', 'whole milk'],
#  ['whole milk'],
#  ['whole milk'],
#  ['rolls/buns', 'bottled water', 'citrus fruit'],
#  ['whole milk'],
#  ['yogurt'],
#  ['root vegetables', 'bottled water'],
#  ['soda'],
#  ['rolls/buns', 'soda'],
#  ['soda'],
#  ['yogurt'],
#  ['whole milk', 'sausage'],
#  ['pastry'],
#  ['rolls/buns'],
#  ['whole milk', 'other vegetables'],
#  ['rolls/buns'],
#  ['other vegetables'],
#  ['whole milk', 'sausage'],
#  ['tropical fruit', 'pastry'],
#  ['yogurt', 'sausage'],
#  ['sausage'],
#  ['soda'],
#  ['whole milk'],
#  ['soda', 'soda'],
#  ['other vegetables', 'root vegetables'],
#  ['tropical fruit'],
#  ['sausage'],
#  ['rolls/buns'],
#  ['other vegetables'],
#  ['root vegetables', 'bottled water', 'citrus fruit'],
#  ['root vegetables'],
#  ['whole milk', 'pastry'],
#  ['sausage'],
#  ['citrus fruit'],
#  ['bottled water'],
#  ['other vegetables', 'sausage'],
#  ['whole milk', 'other vegetables'],
#  ['yogurt'],
#  ['rolls/buns'],
#  ['citrus fruit'],
#  ['other vegetables', 'bottled water'],
#  ['whole milk'],
#  ['other vegetables', 'tropical fruit'],
#  ['whole milk', 'whole milk', 'bottled water'],
#  ['whole milk', 'sausage'],
#  ['other vegetables'],
#  ['rolls/buns', 'citrus fruit', 'pastry'],
#  ['whole milk', 'whole milk'],
#  ['whole milk'],
#  ['whole milk', 'rolls/buns', 'root vegetables'],
#  ['other vegetables'],
#  ['root vegetables', 'bottled water', 'pastry'],
#  ['yogurt'],
#  ['other vegetables', 'rolls/buns', 'soda', 'bottled water'],
#  ['tropical fruit'],
#  ['pastry'],
#  ['other vegetables'],
#  ['whole milk', 'other vegetables'],
#  ['bottled water', 'bottled water'],
#  ['soda'],
#  ['whole milk', 'citrus fruit'],
#  ['soda'],
#  ['rolls/buns', 'soda'],
#  ['other vegetables', 'tropical fruit'],
#  ['rolls/buns'],
#  ['whole milk', 'other vegetables'],
#  ['rolls/buns', 'soda', 'bottled water', 'pastry', 'pastry'],
#  ['soda'],
#  ['root vegetables'],
#  ['whole milk', 'bottled water'],
#  ['soda'],
#  ['whole milk', 'whole milk', 'bottled water'],
#  ['rolls/buns', 'tropical fruit'],
#  ['other vegetables'],
#  ['tropical fruit', 'bottled water'],
#  ['rolls/buns', 'tropical fruit'],
#  ['rolls/buns'],
#  ['other vegetables', 'root vegetables'],
#  ['bottled water'],
#  ['bottled water'],
#  ['soda'],
#  ['whole milk'],
#  ['pastry'],
#  ['soda'],
#  ['yogurt', 'yogurt', 'tropical fruit', 'bottled water'],
#  ['rolls/buns', 'soda'],
#  ['pastry'],
#  ['soda'],
#  ['root vegetables'],
#  ['soda'],
#  ['whole milk', 'whole milk', 'yogurt'],
#  ['soda', 'tropical fruit'],
#  ['tropical fruit'],
#  ['whole milk', 'soda', 'citrus fruit', 'pastry'],
#  ['root vegetables'],
#  ['rolls/buns'],
#  ['rolls/buns', 'soda'],
#  ['whole milk', 'pastry'],
#  ['sausage'],
#  ['whole milk', 'rolls/buns'],
#  ['whole milk'],
#  ['other vegetables'],
#  ['whole milk', 'bottled water'],
#  ['tropical fruit'],
#  ['whole milk'],
#  ['whole milk'],
#  ['whole milk', 'whole milk', 'pastry'],
#  ['whole milk'],
#  ['citrus fruit'],
#  ['soda'],
#  ['other vegetables', 'bottled water'],
#  ['root vegetables'],
#  ['other vegetables'],
#  ['sausage'],
#  ['whole milk', 'rolls/buns'],
#  ['other vegetables', 'other vegetables'],
#  ['other vegetables'],
#  ['whole milk', 'rolls/buns', 'tropical fruit'],
#  ['whole milk'],
#  ['whole milk',
#   'other vegetables',
#   'soda',
#   'bottled water',
#   'sausage',
#   'pastry'],
#  ['whole milk'],
#  ['other vegetables', 'yogurt'],
#  ['whole milk'],
#  ['whole milk'],
#  ['other vegetables'],
#  ['yogurt', 'pastry'],
#  ['whole milk', 'whole milk', 'whole milk', 'rolls/buns'],
#  ['tropical fruit'],
#  ['root vegetables'],
#  ['whole milk', 'tropical fruit'],
#  ['soda'],
#  ['soda'],
#  ['whole milk'],
#  ['yogurt', 'sausage'],
#  ['bottled water'],
#  ['rolls/buns'],
#  ['whole milk', 'whole milk'],
#  ['other vegetables'],
#  ['soda', 'sausage'],
#  ['other vegetables'],
#  ['yogurt'],
#  ['whole milk', 'bottled water'],
#  ['whole milk', 'root vegetables'],
#  ['pastry'],
#  ['other vegetables'],
#  ['other vegetables'],
#  ['whole milk'],
#  ['rolls/buns', 'bottled water'],
#  ['whole milk', 'soda'],
#  ['rolls/buns'],
#  ['rolls/buns'],
#  ['yogurt'],
#  ['other vegetables', 'soda'],
#  ['soda'],
#  ['pastry', 'pastry'],
#  ['other vegetables', 'rolls/buns'],
#  ['rolls/buns', 'citrus fruit'],
#  ['other vegetables', 'rolls/buns'],
#  ['tropical fruit'],
#  ['bottled water'],
#  ['other vegetables', 'soda'],
#  ['soda'],
#  ['other vegetables'],
#  ['other vegetables', 'yogurt', 'root vegetables'],
#  ['whole milk'],
#  ['soda'],
#  ['soda'],
#  ['rolls/buns', 'soda'],
#  ['root vegetables'],
#  ['rolls/buns'],
#  ['rolls/buns', 'root vegetables', 'tropical fruit'],
#  ['root vegetables'],
#  ['other vegetables'],
#  ['rolls/buns'],
#  ['whole milk', 'other vegetables', 'pastry'],
#  ['rolls/buns', 'yogurt'],
#  ['yogurt'],
#  ['rolls/buns', 'sausage'],
#  ['yogurt'],
#  ['other vegetables'],
#  ['yogurt', 'yogurt'],
#  ['pastry'],
#  ['whole milk', 'bottled water'],
#  ['other vegetables', 'root vegetables', 'tropical fruit'],
#  ['soda'],
#  ['sausage'],
#  ['whole milk', 'sausage'],
#  ['other vegetables'],
#  ['sausage'],
#  ['tropical fruit'],
#  ['whole milk', 'sausage', 'sausage'],
#  ['other vegetables'],
#  ['other vegetables', 'other vegetables'],
#  ['rolls/buns'],
#  ['soda', 'sausage'],
#  ['soda'],
#  ['rolls/buns', 'rolls/buns'],
#  ['other vegetables'],
#  ['rolls/buns'],
#  ['whole milk'],
#  ['rolls/buns', 'tropical fruit', 'bottled water', 'bottled water', 'sausage'],
#  ['whole milk', 'other vegetables'],
#  ['whole milk'],
#  ['sausage'],
#  ['tropical fruit', 'sausage'],
#  ['citrus fruit', 'pastry'],
#  ['rolls/buns', 'root vegetables', 'bottled water'],
#  ['whole milk', 'bottled water'],
#  ['whole milk'],
#  ['whole milk', 'soda', 'root vegetables'],
#  ['soda', 'root vegetables'],
#  ['whole milk', 'whole milk'],
#  ['tropical fruit', 'sausage'],
#  ...]

# %% [markdown]
# ## Conclusiones

# %% [markdown]
# - El procesamiento de los datos fue un tanto complicado al ser texto con el cual estaba trabajando, pues al realizar las transacciones de acuerdo a la membresía utilizada y la fecha registrada, no se almacenaban de la manera adecuada por diversos carácteres provocados por espacios y saltos de línea, por lo cual decidí remover dichos carácteres.
#
# - Dentro de los resultados, como era de esperarse, mediante un soporte mínimo más alto, nuestra cantidad de elementos frecuentes disminuye, esto a su vez nos disminuye el total de transacciones frecuentes, pues con soporte mínimo 0.03 obtenemos 13351 transacciones, mientras con un soporte mínimo de 0.05 obtenemos 10174 transacciones.
#
# - Entre los pares más comunes podemos encontrar Leche entera / Yogurh, así como Leche entera / Rolls-buns, lo cual me pareció bastante obvio, pues quien no desea su leche con algún pan.
#
# - De igual manera, si vemos los items de manera individual, el item con mayor frecuencia es la Leche entera, seguido de Vegetales, mientras en los items con menor frecuencia tenemos los productos para cocina y cosméticos para bebé.
